# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/streaming-interruption.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239464-lesson-1-streaming)

# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatOpenAI(model="gpt-4o", temperature=0) 

# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://langchain-ai.github.io/langgraph/how-tos/stream-values/) for [graph state](https://langchain-ai.github.io/langgraph/how-tos/stream-values/):
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Akshat")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content='Hello Akshat! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 13, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVFYaKNSEqikVB4bJgsqoQSal471y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--02a3e83d-1874-4229-8908-5be4a5341102-0', usage_metadata={'input_tokens': 13, 'output_tokens': 12, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Akshat")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hello again, Akshat! How can I help you today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Akshat")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Akshat
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Akshat
# ================================== Ai Message ==================================
#
# Hello Akshat! How can I assist you today?
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Akshat
# ================================== Ai Message ==================================
#
# Hello Akshat! How can I assist you today?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://langchain-ai.github.io/langgraph/how-tos/streaming-from-final-node/#stream-outputs-from-the-final-node), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the latest advancements in quantum computing")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_end. Name: ChatOpenAI
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_end. Name: ChatOpenAI
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the latest advancements in quantum computing")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='As', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' latest', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' updates', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='202', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' computing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' continues', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' make', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' significant', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' strides', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' advancements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' several', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' key', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' areas', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='In', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='creased', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Q', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='ubit', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Count', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' strides', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' advancements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' several', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' key', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' areas', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='In', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='creased', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Q', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='ubit', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Count', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Quality', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Companies', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' like', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' IBM', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Google', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Rig', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='etti', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' working', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' increasing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' number', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Quality', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Companies', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' like', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' IBM', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Google', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Rig', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='etti', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' working', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' increasing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' number', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' qu', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='bits', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' processors', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' IBM', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' instance', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' qu', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='bits', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' processors', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' IBM', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' instance', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' track', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' its', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' roadmap', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' develop', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' processors', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' over', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' track', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' its', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' roadmap', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' develop', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' processors', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' over', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='000', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' qu', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='bits', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' by', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' mid', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='202', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' focus', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' not', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' just', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' increasing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='000', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' qu', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='bits', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' by', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' mid', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='202', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' focus', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' not', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' just', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' increasing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' number', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' qu', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='bits', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' also', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' improving', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' coherence', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' times', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' number', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' qu', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='bits', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' also', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' improving', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' coherence', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' times', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' reducing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' rates', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='Error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Correction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' reducing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' rates', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='Error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Correction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Noise', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Reduction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' correction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' remains', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' critical', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' challenge', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' computing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Noise', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Reduction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' correction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' remains', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' critical', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' challenge', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' computing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Recent', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' advancements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' made', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' developing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' more', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' efficient', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' correction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Recent', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' advancements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' made', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' developing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' more', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' efficient', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' error', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' correction', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' codes', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' techniques', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' mitigate', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' noise', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' These', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' improvements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' crucial', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' codes', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' techniques', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' mitigate', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' noise', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' These', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' improvements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' crucial', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' achieving', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' fault', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='-t', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='oler', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='ant', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' computing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='Quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Algorithms', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Applications', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Researchers', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' developing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' achieving', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' fault', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='-t', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='oler', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='ant', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' computing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='Quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Algorithms', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Applications', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' Researchers', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' developing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' new', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' algorithms', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' that', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' potentially', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' solve', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' complex', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' problems', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# ...
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' common', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' there', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' also', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' development', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' International', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' collaborations', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' common', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' there', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' also', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' competitive', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' aspect', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' nations', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' seek', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' establish', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' leadership', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' competitive', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' aspect', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' nations', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' seek', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' establish', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' leadership', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' this', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' transformative', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' technology', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='These', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' advancements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' indicate', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' that', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' while', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' fully', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' this', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' transformative', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' technology', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='These', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' advancements', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' indicate', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' that', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' while', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' fully', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' realizing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' potential', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' computing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' still', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' work', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' progress', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' significant', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' steps', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' realizing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' potential', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' quantum', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' computing', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' still', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' work', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' progress', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' significant', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' steps', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' being', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' taken', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' towards', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' making', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' it', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' practical', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' impactful', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' technology', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'service_tier': 'default'}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' being', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' taken', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' towards', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' making', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' it', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' practical', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' impactful', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content=' technology', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'service_tier': 'default'}, id='run--b9ff639a-418f-4854-96d4-654f6e9d922f')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the latest advancements in quantum computing")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# |As| of| the| latest| updates| in| |202|3|,| quantum| computing| continues| to| make| significant| strides|,| with| advancements| across| various| aspects| of| the| technology|.| Here| updates| in| |202|3|,| quantum| computing| continues| to| make| significant| strides|,| with| advancements| across| various| aspects| of| the| technology|.| Here| are| some| of| the| key| developments| are| some| of| the| key| developments|:
#
# |1|.| **|In|creased|:
#
# |1|.| **|In|creased| Q|ubit| Count| and| Quality|**|:| Companies| like| IBM|,| Google|,| and| Q|ubit| Count| and| Quality|**|:| Companies| like| IBM|,| Google|,| and| Rig|etti| have| been| working| on| increasing| the| number| of| qu|bits| in| their| quantum| processors|.| IBM|,| for| instance|,| has| been| progressing| towards| Rig|etti| have| been| working| on| increasing| the| number| of| qu|bits| in| their| quantum| processors|.| IBM|,| for| instance|,| has| been| progressing| towards| its| goal| of| a| |1|,|000|-qu|bit| processor|,| with| its| goal| of| a| |1|,|000|-qu|bit| processor|,| with| improvements| in| qu|bit| coherence| times| and| error| rates|.
#
# |2|.| **|Error| Correction| and| improvements| in| qu|bit| coherence| times| and| error| rates|.
#
# |2|.| **|Error| Correction| and| Noise| Reduction|**|:| Error| correction| remains| a| critical| challenge| in| quantum| computing|.| Researchers| are| making| progress| in| developing| more| efficient| quantum| error| correction| codes| and| techniques| to| reduce| Noise| Reduction|**|:| Error| correction| remains| a| critical| challenge| in| quantum| computing|.| Researchers| are| making| progress| in| developing| more| efficient| quantum| error| correction| codes| and| techniques| to| reduce| noise|,| which| is| essential| for| building| reliable| quantum| computers|.
#
# |3|.| **|Quantum| Sup|rem|acy| and| Advantage|**|:| Following| noise|,| which| is| essential| for| building| reliable| quantum| computers|.
#
# |3|.| **|Quantum| Sup|rem|acy| and| Advantage|**|:| Following| Google's| |201|9| claim| of| achieving| quantum| supremacy|,| other| companies| and| research| institutions| have| Google's| |201|9| claim| of| achieving| quantum| supremacy|,| other| companies| and| research| institutions| have| been| working| towards| demonstrating| quantum| advantage| in| practical| applications|.| This| involves| solving| specific| been| working| towards| demonstrating| quantum| advantage| in| practical| applications|.| This| involves| solving| specific| problems| faster| than| classical| computers| can|.
#
# |4|.| **|Hybrid| Quantum|-Class|ical| Algorithms|**|:| There| is| growing| interest| in| problems| faster| than| classical| computers| can|.
#
# |4|.| **|Hybrid| Quantum|-Class|ical| Algorithms|**|:| There| is| growing| interest| in| hybrid| algorithms| that| combine| quantum| and| classical| computing| resources|.| These| algorithms| aim| to| leverage| the| strengths| of| both| types| of| computing| to| solve| hybrid| algorithms| that| combine| quantum| and| classical| computing| resources|.| These| algorithms| aim| to| leverage| the| strengths| of| both| types| of| computing| to| solve| complex| problems| more| efficiently|.
#
# |5|.| **|Quantum| Software| and| Algorithms|**|:| The| development| of| quantum| algorithms| is| advancing|,| complex| problems| more| efficiently|.
#
# |5|.| **|Quantum| Software| and| Algorithms|**|:| The| development| of| quantum| algorithms| is| advancing|,| with| new| algorithms| being| proposed| for| optimization|,| crypt|ography|,| and| material| science|.| Quantum| software| platforms| are| also| with| new| algorithms| being| proposed| for| optimization|,| crypt|ography|,| and| material| science|.| Quantum| software| platforms| are| also| becoming| more| sophisticated|,| making| it| easier| for| developers| to| write| and| test| quantum| programs|.
#
# |6|.| becoming| more| sophisticated|,| making| it| easier| for| developers| to| write| and| test| quantum| programs|.
#
# |6|.| **|Applications| in| Industry|**|:| Various| industries|,| including| pharmaceuticals|,| finance|,| and| logistics|,| are| exploring| quantum| computing| for| **|Applications| in| Industry|**|:| Various| industries|,| including| pharmaceuticals|,| finance|,| and| logistics|,| are| exploring| quantum| computing| for| specific| applications|.| For| example|,| quantum| computing| is| being| used| to| simulate| molecular| specific| applications|.| For| example|,| quantum| computing| is| being| used| to| simulate| molecular| interactions| in| drug| discovery| and| to| optimize| complex| supply| chain| problems|.
#
# |7|.| **|Quantum| Networking| and| Communication|**|:| Progress| is| being| made| in| quantum| communication|,| with| experiments| demonstrating| quantum| key| interactions| in| drug| discovery| and| to| optimize| complex| supply| chain| problems|.
#
# |7|.| **|Quantum| Networking| and| Communication|**|:| Progress| is| being| made| in| quantum| communication|,| with| experiments| demonstrating| quantum| key| distribution| over| longer| distances|.| This| is| a| step| towards| building| a| quantum| internet|,| which| distribution| over| longer| distances|.| This| is| a| step| towards| building| a| quantum| internet|,| which| could| enable| secure| communication| and| distributed| quantum| computing|.
#
# |8|.| **|International| Collaboration| and| Investment|**|:| Governments| and| could| enable| secure| communication| and| distributed| quantum| computing|.
#
# |8|.| **|International| Collaboration| and| Investment|**|:| Governments| and| private| sectors| worldwide| are| investing| heavily| in| quantum| research| and| development|.| International| collaborations| are| forming| to| accelerate| private| sectors| worldwide| are| investing| heavily| in| quantum| research| and| development|.| International| collaborations| are| forming| to| accelerate| progress| and| address| the| challenges| of| building| scalable| quantum| systems|.
#
# |These| advancements| indicate| a| progress| and| address| the| challenges| of| building| scalable| quantum| systems|.
#
# |These| advancements| indicate| a| rapidly| evolving| field| with| the| potential| to| revolution|ize| computing| and| solve| problems| that| are| currently| in|tract|able| rapidly| evolving| field| with| the| potential| to| revolution|ize| computing| and| solve| problems| that| are| currently| in|tract|able| for| classical| computers|.| However|,| significant| technical| challenges| remain|,| and| it| may| still| be| several| years| before| large|-scale| for| classical| computers|.| However|,| significant| technical| challenges| remain|,| and| it| may| still| be| several| years| before| large|-scale|,| fault|-t|oler|ant| quantum| computers| become| a| reality|.||,| fault|-t|oler|ant| quantum| computers| become| a| reality|.||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
#
# The LangGraph API [supports editing graph state](https://langchain-ai.github.io/langgraph/cloud/how-tos/human_in_the_loop_edit_state/#initial-invocation).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()

# %% [markdown]
# Let's [stream `values`](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_values/), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Convert 100 kilometers to miles")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '019a2567-dba2-754d-9914-69c4955669c7', 'attempt': 1})
# StreamPart(event='values', data={'messages': [{'content': 'Convert 100 kilometers to miles', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'bd1f1a56-df5b-4e3f-a75e-7a09813328ae', 'example': False}]})
# StreamPart(event='values', data={'messages': [{'content': 'Convert 100 kilometers to miles', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'bd1f1a56-df5b-4e3f-a75e-7a09813328ae', 'example': False}]})
# StreamPart(event='values', data={'messages': [{'content': 'Convert 100 kilometers to miles', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'bd1f1a56-df5b-4e3f-a75e-7a09813328ae', 'example': False}, {'content': 'To convert kilometers to miles, you can use the conversion factor where 1 kilometer is approximately 0.621371 miles.\n\nSo, to convert 100 kilometers to miles, you multiply:\n\n100 kilometers * 0.621371 miles/kilometer = 62.1371 miles\n\nTherefore, 100 kilometers is approximately 62.1371 miles.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 73, 'prompt_tokens': 134, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVFb0ovxIJirBFKz6bxNiEukoZUag', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--7d5d2674-fbe1-4e28-9494-76970432cd72-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 73, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]})
# StreamPart(event='values', data={'messages': [{'content': 'Convert 100 kilometers to miles', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'bd1f1a56-df5b-4e3f-a75e-7a09813328ae', 'example': False}, {'content': 'To convert kilometers to miles, you can use the conversion factor where 1 kilometer is approximately 0.621371 miles.\n\nSo, to convert 100 kilometers to miles, you multiply:\n\n100 kilometers * 0.621371 miles/kilometer = 62.1371 miles\n\nTherefore, 100 kilometers is approximately 62.1371 miles.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 73, 'prompt_tokens': 134, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVFb0ovxIJirBFKz6bxNiEukoZUag', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--7d5d2674-fbe1-4e28-9494-76970432cd72-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 73, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]})

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Convert 100 kilometers to miles")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# =========================
# content='Convert 100 kilometers to miles' additional_kwargs={} response_metadata={} id='9480d65c-d11a-4c0f-9700-8cd130249ccf'
# =========================
# content="To convert kilometers to miles, you can multiply the number of kilometers by the conversion factor of 0.621371.\n\nLet's calculate that: \n\n100 kilometers * 0.621371 miles/kilometer = 62.1371 miles\n\nSo, 100 kilometers is approximately 62.14 miles." additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 63, 'total_tokens': 197, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 134, 'total_tokens': 197, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVFb9wjr15dtVuVaEJZyiUaXh1Qbl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--d5816f1f-0408-47ca-a0a3-0aec17610ffb-0'
# =========================
# content="To convert kilometers to miles, you can multiply the number of kilometers by the conversion factor of 0.621371.\n\nLet's calculate that: \n\n100 kilometers * 0.621371 miles/kilometer = 62.1371 miles\n\nSo, 100 kilometers is approximately 62.14 miles." additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 63, 'total_tokens': 197, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 134, 'total_tokens': 197, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVFb9wjr15dtVuVaEJZyiUaXh1Qbl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--d5816f1f-0408-47ca-a0a3-0aec17610ffb-0'
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can [use `messages` mode](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_messages/) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Convert 100 kilometers to miles")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event.event)
# Out:
# metadata
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# You can dig further into the types [here](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages).
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Convert 100 kilometers to miles")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata:
                    finish_reason = response_metadata.get("finish_reason", "N/A")
                    print(f"Response Metadata: Finish Reason - {finish_reason}")
                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 019a2568-677a-709f-8f9e-e2cb8d79c629
# --------------------------------------------------
# --------------------------------------------------
# AI: To
# --------------------------------------------------
# AI: To convert
# --------------------------------------------------
# AI: To convert kilometers
# --------------------------------------------------
# AI: To convert kilometers to
# --------------------------------------------------
# AI: To convert kilometers to miles
# --------------------------------------------------
# AI: To convert kilometers to miles,
# --------------------------------------------------
# AI: To convert kilometers to miles, you
# --------------------------------------------------
# AI: To convert kilometers to miles, you can
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer}
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{
# --------------------------------------------------
# --------------------------------------------------
# AI: To
# --------------------------------------------------
# AI: To convert
# --------------------------------------------------
# AI: To convert kilometers
# --------------------------------------------------
# AI: To convert kilometers to
# --------------------------------------------------
# AI: To convert kilometers to miles
# --------------------------------------------------
# AI: To convert kilometers to miles,
# --------------------------------------------------
# AI: To convert kilometers to miles, you
# --------------------------------------------------
# AI: To convert kilometers to miles, you can
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer}
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
#
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
#
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
#
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.137
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
#
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 =
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.137
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
#
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
#
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore,
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14 miles
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14 miles.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14 miles.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14 miles
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14 miles.
# --------------------------------------------------
# AI: To convert kilometers to miles, you can use the conversion factor \(1 \text{ kilometer} = 0.621371 \text{ miles}\).
#
# So, to convert 100 kilometers to miles, you can multiply 100 by 0.621371.
#
# \[100 \times 0.621371 = 62.1371 \]
#
# Therefore, 100 kilometers is approximately 62.14 miles.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
